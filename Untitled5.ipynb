# %%
import os
import urllib
from dotenv import load_dotenv
from datetime import datetime
from dateutil.relativedelta import relativedelta
import json

load_dotenv('Alpaca.env')
kraken_key = os.environ.get('KRAKEN_PUBLIC_KEY')
kraken_secret_key = os.environ.get('KRAKEN_SECRET_KEY')
type(kraken_key)

### Functionality Helper Functions ###
def parse_int(n):
    """
    Securely converts a non-integer value to integer.
    """
    try:
        return int(n)
    except ValueError:
        return float("nan")
    
    
def build_validation_result(is_valid, violated_slot, message_content):
    """
    Define a result message structured as Lex response.
    """
    if message_content is None:
        return {"isValid": is_valid, "violatedSlot": violated_slot}

    return {
        "isValid": is_valid,
        "violatedSlot": violated_slot,
        "message": {"contentType": "PlainText", "content": message_content},
    }


def crypto_price(ticker):
    #BTC- Bitcoin
    if ticker == "XBT":
        bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        xbtresponse = urllib.request.urlopen(bitcoin_api_url)
        xbtdata = json.load(xbtresponse)
        print("the current price of Bitcoin(XBT) is: " + xbtdata['result']['XXBTZUSD']['c'][0])

    #ETH- Ethereum
    if ticker == "ETH":
        api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        ethresponse = urllib.request.urlopen(api_conditions_url)
        ethdata = json.load(ethresponse)
        print("The current price of Ethereum(ETH) is: " + ethdata['result']['XETHZUSD']['c'][0])

    #XRP- Ripple
    if ticker == "XRP":
        ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        xrpresponse = urllib.request.urlopen(ripple_api_url)
        xrpdata = json.load(xrpresponse)
        print("The current price of Ripple(XRP) is: " + xrpdata['result']['XXRPZUSD']['c'][0])

    #DOT- Polkadot
    if ticker == "DOT":
        polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        dotresponse = urllib.request.urlopen(polkadot_api_url)
        poldata = json.load(dotresponse)
        print("The current price of Polkadot(DOT) is: " + poldata['result']['DOTUSD']['c'][0])

    #FIL - Filecoin
    if ticker == "FIL":
        filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        fileresponse = urllib.request.urlopen(filecoin_api_url)
        fildata = json.load(fileresponse)
        #print(fildata)
        print("The current price of filecoin(FIL) is: " + fildata['result']['FILUSD']['c'][0])

    #LINK - chainlink
    if ticker == "LINK":
        chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        chainresponse = urllib.request.urlopen(chainlink_api_url)
        chaindata = json.load(chainresponse)
        #print(chaindata)
        print("The current price of chainlink(LINK) is: " + chaindata['result']['LINKUSD']['c'][0])

    #LTC - Litecoin
    if ticker == "LTC":
        lite_api_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        literesponse = urllib.request.urlopen(lite_api_url)
        litedata = json.load(literesponse)
        #print(litedata)
        print("The current price of Litecoin(LTC) is: " + litedata['result']['XLTCZUSD']['c'][0])

    #ADA - Cardano
    if ticker == "ADA":
        cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        cardanoresponse = urllib.request.urlopen(cardano_api_url)
        cardanodata = json.load(cardanoresponse)
    #print(cardanodata)
        print("The current price of Cardano(ADA) is: " + cardanodata['result']['ADAUSD']['c'][0])

# %%
crypto_price("ETH")
# Out:
# The current price of Ethereum(ETH) is: 2301.00000

# %%
def sell_order(ticker):
    if ticker == "XBT":
        print(input("How much Bitcoin(XBT) would you like to sell?"))
    elif ticker =="ETH":
        print(input("How much Ethereum(ETH) would you like to sell?"))
    elif ticker == "XRP":
        print(input("How much Ripple(XRP) would you like to sell?"))
    elif ticker == "DOT":
        print(input("How much Polkadot(DOT) would you like to sell?"))
    elif ticker == "FIL":
        print(input("How much Filecoin(FIL) would you like to sell?"))
    elif ticker == "LINK":
        print(input("How much Chainlink(LINK) would you like ot sell?"))
    elif ticker == "LTC":
        print(input("How much Litecoin(LTC) would you like to sell?"))
    elif ticker == "ADA":
        print(input("How much Cardano(ADA) would you like to sell?"))

# %%
def buy_order(ticker):
    if ticker == "XBT":
        print(input("How much Bitcoin(XBT) would you like to buy?"))
    elif ticker =="ETH":
        print(input("How much Ethereum(ETH) would you like to buy?"))
    elif ticker == "XRP":
        print(input("How much Ripple(XRP) would you like to buy?"))
    elif ticker == "DOT":
        print(input("How much Polkadot(DOT) would you like to buy?"))
    elif ticker == "FIL":
        print(input("How much Filecoin(FIL) would you like to buy?"))
    elif ticker == "LINK":
        print(input("How much Chainlink(LINK) would you like ot buy?"))
    elif ticker == "LTC":
        print(input("How much Litecoin(LTC) would you like to buy?"))
    elif ticker == "ADA":
        print(input("How much Cardano(ADA) would you like to buy?"))

# %%
#elicit_slot, delegate, lose has to be in the code no matter what

# %%
trading("XBT", "ETH")
# Out:
# Bitcoin(XBT). Which currency would you like to exchange it into?
# How much Bitcoin(XBT) would you like to exchange in Ethereum(ETH)? 2
# 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-40dfa65b6c39> in <module>
# ----> 1 trading("XBT", "ETH")
#
# <ipython-input-24-4e3ae0fa1340> in trading(ticker, exchange)
#       9             print(input("How much Bitcoin(XBT) would you like to exchange in Ethereum(ETH)?"))
#      10             #ask how to do the mathematics in here
# ---> 11             exchange = (xbtdata['result']['XXBTZUSD']['c'][0]) / (ethdata['result']['XETHZUSD']['c'][0])
#      12             exchange = round(exchange, 4)
#
# NameError: name 'xbtdata' is not defined

# %%
import os
import urllib
from dotenv import load_dotenv
from datetime import datetime
from dateutil.relativedelta import relativedelta
import json

load_dotenv('Alpaca.env')
kraken_key = os.environ.get('KRAKEN_PUBLIC_KEY')
kraken_secret_key = os.environ.get('KRAKEN_SECRET_KEY')
#type(kraken_key)

### Functionality Helper Functions ###
def parse_int(n):
    """
    Securely converts a non-integer value to integer.
    """
    try:
        return int(n)
    except ValueError:
        return float("nan")
    
    
def build_validation_result(is_valid, violated_slot, message_content):
    """
    Define a result message structured as Lex response.
    """
    if message_content is None:
        return {"isValid": is_valid, "violatedSlot": violated_slot}

    return {
        "isValid": is_valid,
        "violatedSlot": violated_slot,
        "message": {"contentType": "PlainText", "content": message_content},
    }


def crypto_price(ticker):
    #BTC- Bitcoin
    if ticker == "XBT":
        bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        xbtresponse = urllib.request.urlopen(bitcoin_api_url)
        xbtdata = json.load(xbtresponse)
        print("the current price of Bitcoin(XBT) is: " + xbtdata['result']['XXBTZUSD']['c'][0])

    #ETH- Ethereum
    if ticker == "ETH":
        api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        ethresponse = urllib.request.urlopen(api_conditions_url)
        ethdata = json.load(ethresponse)
        print("The current price of Ethereum(ETH) is: " + ethdata['result']['XETHZUSD']['c'][0])

    #XRP- Ripple
    if ticker == "XRP":
        ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        xrpresponse = urllib.request.urlopen(ripple_api_url)
        xrpdata = json.load(xrpresponse)
        print("The current price of Ripple(XRP) is: " + xrpdata['result']['XXRPZUSD']['c'][0])

    #DOT- Polkadot
    if ticker == "DOT":
        polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        dotresponse = urllib.request.urlopen(polkadot_api_url)
        poldata = json.load(dotresponse)
        print("The current price of Polkadot(DOT) is: " + poldata['result']['DOTUSD']['c'][0])

    #FIL - Filecoin
    if ticker == "FIL":
        filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        fileresponse = urllib.request.urlopen(filecoin_api_url)
        fildata = json.load(fileresponse)
        #print(fildata)
        print("The current price of filecoin(FIL) is: " + fildata['result']['FILUSD']['c'][0])

    #LINK - chainlink
    if ticker == "LINK":
        chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        chainresponse = urllib.request.urlopen(chainlink_api_url)
        chaindata = json.load(chainresponse)
        #print(chaindata)
        print("The current price of chainlink(LINK) is: " + chaindata['result']['LINKUSD']['c'][0])

    #LTC - Litecoin
    if ticker == "LTC":
        lite_api_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        literesponse = urllib.request.urlopen(lite_api_url)
        litedata = json.load(literesponse)
        #print(litedata)
        print("The current price of Litecoin(LTC) is: " + litedata['result']['XLTCZUSD']['c'][0])

    #ADA - Cardano
    if ticker == "ADA":
        cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
        cardanoresponse = urllib.request.urlopen(cardano_api_url)
        cardanodata = json.load(cardanoresponse)
    #print(cardanodata)
        print("The current price of Cardano(ADA) is: " + cardanodata['result']['ADAUSD']['c'][0])
        
def trading(ticker, exchange):
    
    if ticker == "XBT":
        input(("Bitcoin(XBT). Which currency would you like to exchange it into?"))
        if exchange == "XBT":
            print("Sorry, you cannot exchange Bitcoin(XBT) for Bitcoin(XBT). Would you like to make another exchange?")
        elif exchange == "ETH":
            
            bitcoin_ethereum_exchange = int(input("How much Bitcoin(XBT) would you like to exchange in Ethereum(ETH)?"))
            #ask how to do the mathematics in here
            bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=XBTUSD"
            xbtresponse = urllib.request.urlopen(bitcoin_api_url)
            xbtdata = json.load(xbtresponse)
            response12 = xbtdata['result']['XXBTZUSD']['c'][0]
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
            
            exchange = float(response12) / float(response123)
            exchange = round(exchange, 4)
            return exchange * bitcoin_ethereum_exchange
        
        elif exchange == "XRP":
            
            bitcoin_ripple_exchange = int(input("How much Bitcoin(XBT) would you like to exchange in Ripple(XRP)?"))
            
            bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=XBTUSD"
            xbtresponse = urllib.request.urlopen(bitcoin_api_url)
            xbtdata = json.load(xbtresponse)
            response12 = xbtdata['result']['XXBTZUSD']['c'][0]
            
            ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
            xrpresponse = urllib.request.urlopen(ripple_api_url)
            xrpdata = json.load(xrpresponse)
            xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]
            
            exchange = float(response12) / float(xrp_response)
            exchange = round(exchange, 4)
            return exchange * bitcoin_ripple_exchange
        
        elif exchange == "DOT":
            
            bitcoin_polkadot_exchange = int(input("How much Bitcoin(XBT) would you like to exchange in Polkadot(DOT)"))
            
            bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=XBTUSD"
            xbtresponse = urllib.request.urlopen(bitcoin_api_url)
            xbtdata = json.load(xbtresponse)
            response12 = xbtdata['result']['XXBTZUSD']['c'][0]
            
            polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair=DOTUSD"
            dotresponse = urllib.request.urlopen(polkadot_api_url)
            poldata = json.load(dotresponse)
            pol_response = poldata['result']['DOTUSD']['c'][0]
            
            exchange = float(response12) / float(pol_response)
            exchange = round(exchange, 4)
            return exchange * bitcoin_polkadot_exchange
        
        elif exchange == "FIL":
            
            bitcoin_filecoin_exchange = int(input("How much Bitcoin(XBT) would you like to exchange in Filecoin(FIL)"))
            
            bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=XBTUSD"
            xbtresponse = urllib.request.urlopen(bitcoin_api_url)
            xbtdata = json.load(xbtresponse)
            response12 = xbtdata['result']['XXBTZUSD']['c'][0]
            
            
            filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=FILUSD"
            fileresponse = urllib.request.urlopen(filecoin_api_url)
            fildata = json.load(fileresponse)
            file_response = fildata['result']['FILUSD']['c'][0]
            
            exchange = float(response12) / float(file_response)
            exchange = round(exchange, 4)
            return exchange * bitcoin_filecoin_exchange
        
        
        elif exchange == "LINK":
            
            bitcoin_chainlink_exchange = int(input("How much Bitcoin(XBT) would you like to exchange in Chainlink(LINK)?"))
            
            bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=XBTUSD"
            xbtresponse = urllib.request.urlopen(bitcoin_api_url)
            xbtdata = json.load(xbtresponse)
            response12 = xbtdata['result']['XXBTZUSD']['c'][0]
            
            chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair=LINKUSD"
            chainresponse = urllib.request.urlopen(chainlink_api_url)
            chaindata = json.load(chainresponse)
            chain_response = chaindata['result']['LINKUSD']['c'][0]
            
            exchange = float(response12) / float(chain_response)
            exchange = round(exchange, 4)
            return exchange * bitcoin_chainlink_exchange
            
            
        elif exchange =="LTC":
            
            bitcoin_litecoin_exchange = int(input("How much Bitcoin(XBT) would you like to exchange in Litecoin(LTC)?"))
            
            bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=XBTUSD"
            xbtresponse = urllib.request.urlopen(bitcoin_api_url)
            xbtdata = json.load(xbtresponse)
            response12 = xbtdata['result']['XXBTZUSD']['c'][0]
            
            litecoin_api_url ="https://api.kraken.com/0/public/Ticker?pair=LTCUSD"
            literesponse = urllib.request.urlopen(litecoin_api_url)
            litedata = json.load(literesponse)
            lite_response = litedata['result']['XLTCZUSD']['c'][0]
            
            exchange = float(response12)/ float(lite_response)
            exchange = round(exchange, 4)
            return exchange * bitcoin_litecoin_exchange
        
        elif exchange == "ADA":
            
            bitcoin_cardano_exchange = int(input("How much Bitcoin(XBT) would you like to exchange in Cardano(ADA)?"))
            
            bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=XBTUSD"
            xbtresponse = urllib.request.urlopen(bitcoin_api_url)
            xbtdata = json.load(xbtresponse)
            response12 = xbtdata['result']['XXBTZUSD']['c'][0]
            
            cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair=ADAUSD"
            cardanoresponse = urllib.request.urlopen(cardano_api_url)
            cardanodata = json.load(cardanoresponse)
            cardano_response = cardanodata['result']['ADAUSD']['c'][0]
            
            exchange = float(response12) / float(cardano_response)
            exchange = round(exchange, 4)
            return exchange * bitcoin_cardano_exchange
        
        else:
            print("Due to incorrect exchange pick, we are unable to make an exchange currently!")
    
    if ticker == "ETH":
        input(("Ethereum(ETH). Which currency would you like to exchange it into?"))
        if exchange == "ETH":
            print("Sorry, you cannot exchange Ethereum(ETH) for Ethereum(ETH). Would you like to make another exchange?")
        elif exchange == "XBT":
            
            ethereum_bitcoin_exchange = int(input("How much Ethereum(ETH) would you like to exchange in Bitcoin(XBT)?"))
            #ask how to do the mathematics in here
            bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=XBTUSD"
            xbtresponse = urllib.request.urlopen(bitcoin_api_url)
            xbtdata = json.load(xbtresponse)
            response12 = xbtdata['result']['XXBTZUSD']['c'][0]
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
            
            exchange = float(response123) / float(response12)
            exchange = round(exchange, 4)
            return exchange * ethereum_bitcoin_exchange
        
        elif exchange == "XRP":
            
            ethereum_ripple_exchange = int(input("How much Ethereum(ETH) would you like to exchange in Ripple(XRP)?"))
            
                        
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
 
            
            ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
            xrpresponse = urllib.request.urlopen(ripple_api_url)
            xrpdata = json.load(xrpresponse)
            xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]
            
            exchange = float(response123) / float(xrp_response)
            exchange = round(exchange, 4)
            return exchange * ethereum_ripple_exchange
        
        elif exchange == "DOT":
            
            ethereum_polkadot_exchange = int(input("How much Ethereum(ETH) would you like to exchange in Polkadot(DOT)"))
              
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
 
            
            polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair=DOTUSD"
            dotresponse = urllib.request.urlopen(polkadot_api_url)
            poldata = json.load(dotresponse)
            pol_response = poldata['result']['DOTUSD']['c'][0]
            
            exchange = float(response123) / float(pol_response)
            exchange = round(exchange, 4)
            return exchange * ethereum_polkadot_exchange
        
        elif exchange == "FIL":
            
            ethereum_filecoin_exchange = int(input("How much Ethereum(ETH) would you like to exchange in Filecoin(FIL)"))
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
 
            filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=FILUSD"
            fileresponse = urllib.request.urlopen(filecoin_api_url)
            fildata = json.load(fileresponse)
            file_response = fildata['result']['FILUSD']['c'][0]
            
            exchange = float(response123) / float(file_response)
            exchange = round(exchange, 4)
            return exchange * ethereum_filecoin_exchange
        
        
        elif exchange == "LINK":
            
            ethereum_chainlink_exchange = int(input("How much Ethereum(ETH) would you like to exchange in Chainlink(LINK)?"))
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
 
            chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair=LINKUSD"
            chainresponse = urllib.request.urlopen(chainlink_api_url)
            chaindata = json.load(chainresponse)
            chain_response = chaindata['result']['LINKUSD']['c'][0]
            
            exchange = float(response123) / float(chain_response)
            exchange = round(exchange, 4)
            return exchange * ethereum_chainlink_exchange
            
            
        elif exchange =="LTC":
            
            ethereum_litecoin_exchange = int(input("How much Ethereum(ETH) would you like to exchange in Litecoin(LTC)?"))
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
 
            
            litecoin_api_url ="https://api.kraken.com/0/public/Ticker?pair=LTCUSD"
            literesponse = urllib.request.urlopen(litecoin_api_url)
            litedata = json.load(literesponse)
            lite_response = litedata['result']['XLTCZUSD']['c'][0]
            
            exchange = float(response123)/ float(lite_response)
            exchange = round(exchange, 4)
            return exchange * ethereum_litecoin_exchange
        
        elif exchange == "ADA":
            
            ethereum_cardano_exchange = int(input("How much Ethereum(ETH) would you like to exchange in Cardano(ADA)?"))
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
 
            cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair=ADAUSD"
            cardanoresponse = urllib.request.urlopen(cardano_api_url)
            cardanodata = json.load(cardanoresponse)
            cardano_response = cardanodata['result']['ADAUSD']['c'][0]
            
            exchange = float(response123) / float(cardano_response)
            exchange = round(exchange, 4)
            return exchange * ethereum_cardano_exchange
    if ticker == "XRP":
        input(("Ripple(XRP). Which currency would you like to exchange it into?"))
        if exchange == "XRP":
            print("Sorry, you cannot exchange Ripple(XRP) for Ripple(XRP). Would you like to make another exchange?")
        elif exchange == "XBT":
            bitcoin_ripple_exchange = int(input("How much Ripple(XRP) would you like to exchange in Bitcoin(XBT)"))
            
            ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
            xrpresponse = urllib.request.urlopen(ripple_api_url)
            xrpdata = json.load(xrpresponse)
            xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]

            bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=XBTUSD"
            xbtresponse = urllib.request.urlopen(bitcoin_api_url)
            xbtdata = json.load(xbtresponse)
            response12 = xbtdata['result']['XXBTZUSD']['c'][0]
            
            exchange = float(xrp_response)/float(response12)
            exchange = round(exchange, 4)
            return exchange * bitcoin_ripple_exchange
        
        elif exchange == "ETH":
            ethereum_ripple_exchange = int(input("How much Ripple(XRP) would you like to exchange in Ethereum(ETH)?"))
            
            ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
            xrpresponse = urllib.request.urlopen(ripple_api_url)
            xrpdata = json.load(xrpresponse)
            xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
            
            exchange = float(xrp_reponse)/ float(response123)
            exchange = round(exchange, 4)
            return exchange * ethereum_ripple_exchange
        
        elif exchange == "DOT":
            polkadot_ripple_exchange = int(input("How much Ripple(XRP) would you like to exchange in Polkadot(DOT)?"))
            
            ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
            xrpresponse = urllib.request.urlopen(ripple_api_url)
            xrpdata = json.load(xrpresponse)
            xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]
            
            polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair=DOTUSD"
            dotresponse = urllib.request.urlopen(polkadot_api_url)
            poldata = json.load(dotresponse)
            pol_response = poldata['result']['DOTUSD']['c'][0]
            
            exchange = float(xrp_response)/ float(pol_response)
            exchange = round(exchange, 4)
            return exchange * polkadot_ripple_exchange
        
        elif exchange == "FIL":
            filecoin_ripple_exchange = int(input("How much Ripple(XRP) would you like to exchange in Filecoin(FIL)?"))
            
            ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
            xrpresponse = urllib.request.urlopen(ripple_api_url)
            xrpdata = json.load(xrpresponse)
            xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]
            
            filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=FILUSD"
            fileresponse = urllib.request.urlopen(filecoin_api_url)
            fildata = json.load(fileresponse)
            file_response = fildata['result']['FILUSD']['c'][0]
            
            exchange = float(xrp_response)/ float(file_response)
            exchange = round(exchange, 4)
            return exchange * filecoin_ripple_exchange
        
        elif exchange == "LINK":
            chainlink_ripple_exchange = int(input("How much Ripple(XRP) would you like to exchange in Chainlink(LINK)?"))
            
            ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
            xrpresponse = urllib.request.urlopen(ripple_api_url)
            xrpdata = json.load(xrpresponse)
            xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]
            
            chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair=LINKUSD"
            chainresponse = urllib.request.urlopen(chainlink_api_url)
            chaindata = json.load(chainresponse)
            chain_response = chaindata['result']['LINKUSD']['c'][0]
            
            exchange = float(xrp_response)/ float(chain_response)
            exchange = round(exchange, 4)
            return exchange * chainlink_ripple_exchange
        
        elif exchange == "LTC":
            litecoin_ripple_exchange = int(input("How much Ripple(XRP) would you like to exchange in Litecoin(LTC)?"))
            
            ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
            xrpresponse = urllib.request.urlopen(ripple_api_url)
            xrpdata = json.load(xrpresponse)
            xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]
            
            litecoin_api_url ="https://api.kraken.com/0/public/Ticker?pair=LTCUSD"
            literesponse = urllib.request.urlopen(litecoin_api_url)
            litedata = json.load(literesponse)
            lite_response = litedata['result']['XLTCZUSD']['c'][0]
            
            exchange = float(xrp_response)/float(lite_response)
            exchange = round(exchange, 4)
            return exchange * litecoin_ripple_exchange
        
        elif exchange == "ADA":
            cardano_ripple_exchange = int(input("How much Ripple(XRP) would you like to exchange in Cardano(ADA)?"))
            
            ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
            xrpresponse = urllib.request.urlopen(ripple_api_url)
            xrpdata = json.load(xrpresponse)
            xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]
            
            cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair=ADAUSD"
            cardanoresponse = urllib.request.urlopen(cardano_api_url)
            cardanodata = json.load(cardanoresponse)
            cardano_response = cardanodata['result']['ADAUSD']['c'][0]
            
            exchange = float(xrp_response)/float(cardano_response)
            exchange = round(exchange, 4)
            return exchange * cardano_ripple_exchange
    if ticker == "DOT":
        input(("Polkadot(DOT). Which currency would you like to exchange it into?"))
        if exchange == "XRP":
            print("Sorry, you cannot exchange Polkadot(DOT) for Polkadot(DOT). Would you like to make another exchange?")
        elif exchange == "XBT":
            bitcoin_polkadot_exchange = int(input("How much Polkadot(DOT) would you like to exchange in Bitcoin(XBT)"))
            
            polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair=DOTUSD"
            dotresponse = urllib.request.urlopen(polkadot_api_url)
            poldata = json.load(dotresponse)
            pol_response = poldata['result']['DOTUSD']['c'][0]

            bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=XBTUSD"
            xbtresponse = urllib.request.urlopen(bitcoin_api_url)
            xbtdata = json.load(xbtresponse)
            response12 = xbtdata['result']['XXBTZUSD']['c'][0]
            
            exchange = float(pol_response)/float(response12)
            exchange = round(exchange, 4)
            return exchange * bitcoin_polkadot_exchange
        
        elif exchange == "ETH":
            ethereum_polkadot_exchange = int(input("How much Polkadot(DOT) would you like to exchange in Ethereum(ETH)?"))
            
            polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair=DOTUSD"
            dotresponse = urllib.request.urlopen(polkadot_api_url)
            poldata = json.load(dotresponse)
            pol_response = poldata['result']['DOTUSD']['c'][0]
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
            
            exchange = float(pol_response)/float(response123)
            exchange = round(exchange, 4)
            return exchange * ethereum_polkadot_exchange
        elif exchange == "XRP":
            ripple_polkadot_exchange = int(input("How much Polkadot(DOT) would you like to exchange in Ripple(XRP)?"))
            
            polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair=DOTUSD"
            dotresponse = urllib.request.urlopen(polkadot_api_url)
            poldata = json.load(dotresponse)
            pol_response = poldata['result']['DOTUSD']['c'][0]
            
            ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
            xrpresponse = urllib.request.urlopen(ripple_api_url)
            xrpdata = json.load(xrpresponse)
            xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]
            
            exchange = float(pol_response) / float(xrp_response)
            exchange = round(exchange, 4)
            return exchange * ripple_polkadot_exchange
        
        elif exchange == "FIL":
            filecoin_polkadot_exchange = int(input("How much Polkadot(DOT) would you like to exchange in Filecoin(FIL)?"))
            
            polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair=DOTUSD"
            dotresponse = urllib.request.urlopen(polkadot_api_url)
            poldata = json.load(dotresponse)
            pol_response = poldata['result']['DOTUSD']['c'][0]
            
            filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=FILUSD"
            fileresponse = urllib.request.urlopen(filecoin_api_url)
            fildata = json.load(fileresponse)
            file_response = fildata['result']['FILUSD']['c'][0]
            
            exchange = float(pol_response) / float(file_response)
            exchange = round(exchange, 4)
            return exchange * filecoin_polkadot_exchange
        
        elif exchange == "LINK":
            chainlink_polkadot_exchange = int(input("How much Polkadot(DOT) would you like to exchange in Chainlink(LINK)?"))
            
            polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair=DOTUSD"
            dotresponse = urllib.request.urlopen(polkadot_api_url)
            poldata = json.load(dotresponse)
            pol_response = poldata['result']['DOTUSD']['c'][0]
            
            chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair=LINKUSD"
            chainresponse = urllib.request.urlopen(chainlink_api_url)
            chaindata = json.load(chainresponse)
            chain_response = chaindata['result']['LINKUSD']['c'][0]
            
            exchange = float(pol_response) / float(chain_response)
            exchange = round(exchange, 4)
            return exchange * chainlink_polkadot_exchange
        
        elif exchange == "LTC":
            litecoin_polkadot_exchange = int(input("How much Polkadot(DOT) would you like to exchange in Litecoin(LTC)?"))
            
            polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair=DOTUSD"
            dotresponse = urllib.request.urlopen(polkadot_api_url)
            poldata = json.load(dotresponse)
            pol_response = poldata['result']['DOTUSD']['c'][0]
            
            litecoin_api_url ="https://api.kraken.com/0/public/Ticker?pair=LTCUSD"
            literesponse = urllib.request.urlopen(litecoin_api_url)
            litedata = json.load(literesponse)
            lite_response = litedata['result']['XLTCZUSD']['c'][0]
            
            exchange = float(pol_response)/ float(lite_response)
            exchange = round(exchange, 4)
            return exchange * litecoin_polkadot_exchange
        
        elif exchange == "ADA":
            cardano_polkadot_exchange = int(input("How much Polkadot(DOT) would you like to exchange in Cardano(ADA)?"))
            
            polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair=DOTUSD"
            dotresponse = urllib.request.urlopen(polkadot_api_url)
            poldata = json.load(dotresponse)
            pol_response = poldata['result']['DOTUSD']['c'][0]
            
            cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair=ADAUSD"
            cardanoresponse = urllib.request.urlopen(cardano_api_url)
            cardanodata = json.load(cardanoresponse)
            cardano_response = cardanodata['result']['ADAUSD']['c'][0]
            
            exchange = float(pol_response) / float(cardano_response)
            exchange = round(exchange, 4)
            return exchange* cardano_polkadot_exchange
   
    if ticker == "FIL":
        input(("Filecoin(FIL). Which currency would you like to exchange it into?"))
        if exchange == "FIL":
            print("Sorry, you cannot exchange Filecoin(FIL) for Filecoin(FIL). Would you like to make another exchange?")
        elif exchange == "XBT":
            bitcoin_filecoin_exchange = int(input("How much Filecoin(FIL) would you like to exchange in Bitcoin(XBT)?"))
            
            filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=FILUSD"
            fileresponse = urllib.request.urlopen(filecoin_api_url)
            fildata = json.load(fileresponse)
            file_response = fildata['result']['FILUSD']['c'][0]
            
            bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=XBTUSD"
            xbtresponse = urllib.request.urlopen(bitcoin_api_url)
            xbtdata = json.load(xbtresponse)
            response12 = xbtdata['result']['XXBTZUSD']['c'][0]
            
            exchange = float(file_response) / float(response12)
            exchange = round(exchange, 4)
            return exchange * bitcoin_filecoin_exchange
        
        elif exchange == "ETH":
            ethereum_filecoin_exchange = int(input("How much Filecoin(FIL) would you like to exchange in Ethereum(ETH)?"))
            
            filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=FILUSD"
            fileresponse = urllib.request.urlopen(filecoin_api_url)
            fildata = json.load(fileresponse)
            file_response = fildata['result']['FILUSD']['c'][0]
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
            
            exchange = float(file_response) / float(response123)
            exchange=round(exchange, 4)
            return exchange * ethereum_filecoin_exchange
        
        elif exchange == "XRP":
            ripple_filecoin_exchange = int(input("How much Filecoin(FIL) would you like to exchange in Ripple(XRP)?"))
            
            filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=FILUSD"
            fileresponse = urllib.request.urlopen(filecoin_api_url)
            fildata = json.load(fileresponse)
            file_response = fildata['result']['FILUSD']['c'][0]
            
            ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
            xrpresponse = urllib.request.urlopen(ripple_api_url)
            xrpdata = json.load(xrpresponse)
            xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]
            
            exchange = float(file_response) / float(xrp_response)
            exchange = round(exchange, 4)
            return exchange * ripple_filecoin_exchange
        
        elif exchange == "DOT":
            polkadot_filecoin_exchange = int(input("How much Filecoin(FIL) would you like to exchange in Polkadot(DOT)?"))
            
            filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=FILUSD"
            fileresponse = urllib.request.urlopen(filecoin_api_url)
            fildata = json.load(fileresponse)
            file_response = fildata['result']['FILUSD']['c'][0]
            
            polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair=DOTUSD"
            dotresponse = urllib.request.urlopen(polkadot_api_url)
            poldata = json.load(dotresponse)
            pol_response = poldata['result']['DOTUSD']['c'][0]
            
            exchange = float(file_response) / float(pol_response)
            exchange = round(exchange, 4)
            return exchange * polkadot_filecoin_exchange
        elif exchange == "LINK":
            chainlink_filecoin_exchange = int(input("How much Filecoin(FIL) would you like to exchange in Chainlink(LINK)?"))
            
            filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=FILUSD"
            fileresponse = urllib.request.urlopen(filecoin_api_url)
            fildata = json.load(fileresponse)
            file_response = fildata['result']['FILUSD']['c'][0]
            
            chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair=LINKUSD"
            chainresponse = urllib.request.urlopen(chainlink_api_url)
            chaindata = json.load(chainresponse)
            chain_response = chaindata['result']['LINKUSD']['c'][0]
            
            exchange = float(file_response) / float(chain_response)
            exchange = round(exchange, 4)
            return exchange * chainlink_filecoin_exchange
            
        elif exchange == "LTC":
            litecoin_filecoin_exchange = int(input("How much Filecoin(FIL) would you like to exchange in Litecoin(LTC))?"))
            
            filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=FILUSD"
            fileresponse = urllib.request.urlopen(filecoin_api_url)
            fildata = json.load(fileresponse)
            file_response = fildata['result']['FILUSD']['c'][0]
            
            litecoin_api_url ="https://api.kraken.com/0/public/Ticker?pair=LTCUSD"
            literesponse = urllib.request.urlopen(litecoin_api_url)
            litedata = json.load(literesponse)
            lite_response = litedata['result']['XLTCZUSD']['c'][0]
            
            exchange = float(file_response) / float(lite_response)
            exchange = round(exchange, 4)
            return exchange * litecoin_filecoin_exchange
        
        elif exchange == "ADA":
            cardano_filecoin_exchange = int(input("How much Filecoin(FIL) would you like to exchange in Cardano(ADA)?"))
            
            filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=FILUSD"
            fileresponse = urllib.request.urlopen(filecoin_api_url)
            fildata = json.load(fileresponse)
            file_response = fildata['result']['FILUSD']['c'][0]
            
            cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair=ADAUSD"
            cardanoresponse = urllib.request.urlopen(cardano_api_url)
            cardanodata = json.load(cardanoresponse)
            cardano_response = cardanodata['result']['ADAUSD']['c'][0]
            
            exchange = float(file_Response)/float(cardano_response)
            exchange = round(exchange, 4)
            return exchange * cardano_filecoin_exchange
    if ticker == "LINK":
        input(("Chainlink(LINK). Which currency would you like to exchange it into?"))
        if exchange == "LINK":
            print("Sorry, you cannot exchange Chainlink(LINK) for Chainlink(LINK). Would you like to make another exchange?")
        elif exchange == "XBT":
            bitcoin_chainlink_exchange = int(input("How much Chainlink(LINK) would you like to exchange in Bitcoin(XBT)?"))
            
            chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair=LINKUSD"
            chainresponse = urllib.requestest.urlopen(chainlink_api_url)
            chaindata = json.load(chainresponse)
            chain_response = chaindata['result']['LINKUSD']['c'][0]
            
            bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=XBTUSD"
            xbtresponse = urllib.request.urlopen(bitcoin_api_url)
            xbtdata = json.load(xbtresponse)
            response12 = xbtdata['result']['XXBTZUSD']['c'][0]
            
            exchange = float(chain_response) / float(response12)
            exchange = round(exchange, 4)
            return exchange*bitcoin_chainlink_exchange
        elif exchange == "ETH":
            ethereum_chainlink_exchange = int(input("How much Chainlink(LINK) would you like to exchange in Ethereum(ETH)?"))
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
            
            chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair=LINKUSD"
            chainresponse = urllib.requestest.urlopen(chainlink_api_url)
            chaindata = json.load(chainresponse)
            chain_response = chaindata['result']['LINKUSD']['c'][0]
            
            exchange = float(chain_response) / float(response123)
            exchange = round(exchange, 4)
            return exchange * ethereum_chainlin_exchange
        
        elif exchange == "XRP":
            chainlink_ripple_exchange = int(input("How much Chainlink(LINK) would you like to exchange in Ripple(XRP)?"))
            
            ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
            xrpresponse = urllib.request.urlopen(ripple_api_url)
            xrpdata = json.load(xrpresponse)
            xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]
            
            chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair=LINKUSD"
            chainresponse = urllib.requestest.urlopen(chainlink_api_url)
            chaindata = json.load(chainresponse)
            chain_response = chaindata['result']['LINKUSD']['c'][0]
            
            exchange = float(chain_response) / float(xrp_response)
            exchange = round(exchange, 4)
            return exchange * chainlink_ripple_exchange
        elif exchange == "DOT":
            chainlink_polkadot_exchange = int(input("How much Chainlink(LINK) would you like to exchange in Polkadot(DOT)?"))
            
            polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair=DOTUSD"
            dotresponse = urllib.request.urlopen(polkadot_api_url)
            poldata = json.load(dotresponse)
            pol_response = poldata['result']['DOTUSD']['c'][0]
            
            chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair=LINKUSD"
            chainresponse = urllib.requestest.urlopen(chainlink_api_url)
            chaindata = json.load(chainresponse)
            chain_response = chaindata['result']['LINKUSD']['c'][0]
            
            exchange = float(chain_response)/float(pol_response)
            exchange = round(exchange, 4)
            return exchange * chainlink_polkadot_exchange
        elif exchange == "FIL":
            chainlink_filecoin_exchange = int(input("How much Chainlink(LINK) would you like to exchange in Filecoin(FIL)?"))
            
            filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=FILUSD"
            fileresponse = urllib.request.urlopen(filecoin_api_url)
            fildata = json.load(fileresponse)
            file_response = fildata['result']['FILUSD']['c'][0]
            
            chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair=LINKUSD"
            chainresponse = urllib.requestest.urlopen(chainlink_api_url)
            chaindata = json.load(chainresponse)
            chain_response = chaindata['result']['LINKUSD']['c'][0]
            
            exchange = float(chain_response)/float(file_response)
            exchange = round(exchange, 4)
            return exchange * chainlink_filecoin_exchange
        elif exchange == "LTC":
            chainlink_litecoin_exchange = int(input("How much Chainlink(LINK) would you like to exchange in Litecoin(LTC)?"))
            
            litecoin_api_url ="https://api.kraken.com/0/public/Ticker?pair=LTCUSD"
            literesponse = urllib.request.urlopen(litecoin_api_url)
            litedata = json.load(literesponse)
            lite_response = litedata['result']['XLTCZUSD']['c'][0]
            
            chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair=LINKUSD"
            chainresponse = urllib.requestest.urlopen(chainlink_api_url)
            chaindata = json.load(chainresponse)
            chain_response = chaindata['result']['LINKUSD']['c'][0]
            
            exchange = float(chain_response)/float(lite_response)
            exchange = round(exchange, 4)
            return exchange * chainlink_litecoin_exchange
        elif exchange == "ADA":
            chainlink_cardano_exchange = int(input("How much Chainlink(LINK) would you like to exchange in Cardano(ADA)?"))
            
            cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair=ADAUSD"
            cardanoresponse = urllib.request.urlopen(cardano_api_url)
            cardanodata = json.load(cardanoresponse)
            cardano_response = cardanodata['result']['ADAUSD']['c'][0]
            
            chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair=LINKUSD"
            chainresponse = urllib.requestest.urlopen(chainlink_api_url)
            chaindata = json.load(chainresponse)
            chain_response = chaindata['result']['LINKUSD']['c'][0]
            
            exchange = float(chain_response)/float(cardano_response)
            exchange = round(exchange, 4)
            return exchange * chainlink_cardano_exchange
        
    if ticker =="LTC":
        input("Litecoin(LTC). Which currency would you like to exchange it into?")
        if exchange == "LTC":
            print("Sorry, you cannot exchange Litecoin(LTC) for Litecoin(LTC). Would you like to make another exchange?")
        elif exchange == "XBT":
            litecoin_bitcoin_exchange = int(input("How much Litecoin(LTC) would you like to exchange in Bitcoin(XBT)?"))
            
            bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=XBTUSD"
            xbtresponse = urllib.request.urlopen(bitcoin_api_url)
            xbtdata = json.load(xbtresponse)
            response12 = xbtdata['result']['XXBTZUSD']['c'][0]
            
            litecoin_api_url ="https://api.kraken.com/0/public/Ticker?pair=LTCUSD"
            literesponse = urllib.request.urlopen(litecoin_api_url)
            litedata = json.load(literesponse)
            lite_response = litedata['result']['XLTCZUSD']['c'][0]
            
            exchange = float(lite_response)/float(response12)
            exchange = round(exchange, 4)
            return exchange * litecoin_bitcoin_exchange
        
        elif exchange == "ETH":
            litecoin_ethereum_exchange = int(input("How much Litecoin(LTC) would you like to exchange in Ethereum(ETH)?"))
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
            
            litecoin_api_url ="https://api.kraken.com/0/public/Ticker?pair=LTCUSD"
            literesponse = urllib.request.urlopen(litecoin_api_url)
            litedata = json.load(literesponse)
            lite_response = litedata['result']['XLTCZUSD']['c'][0]
            
            exchange = float(lite_response)/float(response123)
            exchange = round(exchange, 4)
            return exchange * litecoin_ethreum_exchange
        elif exchange =="XRP":
            litecoin_ripple_exchange = int(input("How much Litecoin(LTC) would you like to exchange in Ripple(XRP)?"))
            
            ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
            xrpresponse = urllib.request.urlopen(ripple_api_url)
            xrpdata = json.load(xrpresponse)
            xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]
            
            litecoin_api_url ="https://api.kraken.com/0/public/Ticker?pair=LTCUSD"
            literesponse = urllib.request.urlopen(litecoin_api_url)
            litedata = json.load(literesponse)
            lite_response = litedata['result']['XLTCZUSD']['c'][0]
            
            exchange = float(lite_response)/float(xrp_response)
            exchange = round(exchange, 4)
            return exchange * litecoin_ripple_exchange
        elif exchange == "DOT":
            litecoin_polkadot_exchange=int(input("How much Litecoin(LTC) would you like to exchange in Polkadot(DOT)?"))
            
            polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair=DOTUSD"
            dotresponse = urllib.request.urlopen(polkadot_api_url)
            poldata = json.load(dotresponse)
            pol_response = poldata['result']['DOTUSD']['c'][0]
            
            litecoin_api_url ="https://api.kraken.com/0/public/Ticker?pair=LTCUSD"
            literesponse = urllib.request.urlopen(litecoin_api_url)
            litedata = json.load(literesponse)
            lite_response = litedata['result']['XLTCZUSD']['c'][0]
            
            exchange = float(lite_response)/float(pol_response)
            exchange = round(exchange, 4)
            return exchange*litecoin_polkadot_exchange
        elif exchange =="FIL":
            litecoin_filecoin_exchange = int(input("How much Litecoin(LTC) would you like to exchange in Filecoin(FIL)?"))
            
            filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=FILUSD"
            fileresponse = urllib.request.urlopen(filecoin_api_url)
            fildata = json.load(fileresponse)
            file_response = fildata['result']['FILUSD']['c'][0]
            
            litecoin_api_url ="https://api.kraken.com/0/public/Ticker?pair=LTCUSD"
            literesponse = urllib.request.urlopen(litecoin_api_url)
            litedata = json.load(literesponse)
            lite_response = litedata['result']['XLTCZUSD']['c'][0]
            
            exchange = float(lite_response)/float(file_response)
            exchange = round(exchange, 4)
            return exchange * litecoin_filecoin_exchange
        elif exchange =="LINK":
            litecoin_chainlink_exchange = int(input("How much Litecoin(LTC) would you like to exchange in Chainlink(LINK)?"))
            
            chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair=LINKUSD"
            chainresponse = urllib.requestest.urlopen(chainlink_api_url)
            chaindata = json.load(chainresponse)
            chain_response = chaindata['result']['LINKUSD']['c'][0]
            
            litecoin_api_url ="https://api.kraken.com/0/public/Ticker?pair=LTCUSD"
            literesponse = urllib.request.urlopen(litecoin_api_url)
            litedata = json.load(literesponse)
            lite_response = litedata['result']['XLTCZUSD']['c'][0]
            
            exchange = float(lite_response)/float(chain_response)
            exchange = round(exchange, 4)
            return exchange * litecoin_chainlink_exchange
        elif exchange == "ADA":
            litecoin_cardano_exchange = int(input("How much Litecoin(LTC) would you like to exchange in Cardano(ADA)?"))
            
            cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair=ADAUSD"
            cardanoresponse = urllib.request.urlopen(cardano_api_url)
            cardanodata = json.load(cardanoresponse)
            cardano_response = cardanodata['result']['ADAUSD']['c'][0]
            
            litecoin_api_url ="https://api.kraken.com/0/public/Ticker?pair=LTCUSD"
            literesponse = urllib.request.urlopen(litecoin_api_url)
            litedata = json.load(literesponse)
            lite_response = litedata['result']['XLTCZUSD']['c'][0]
            
            exchange = float(lite_response)/float(cardano_response)
            exchange = round(exchange, 4)
            return exchange*litecoin_cardano_exchange
    if ticker == "ADA":
        input("Cardano(ADA). Which currency would you like to exchange it into?")
        if exchange =="ADA":
            print("Sorry, you cannot exchange Cardano(ADA) for Cardano(ADA). Would you like to make another exchange?")
        elif exchange =="XBT":
            cardano_bitcoin_exchange = int(input("How much Cardano(ADA) would you like to exchange in Bitcoin(XBT)?"))
            
            bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=XBTUSD"
            xbtresponse = urllib.request.urlopen(bitcoin_api_url)
            xbtdata = json.load(xbtresponse)
            response12 = xbtdata['result']['XXBTZUSD']['c'][0]
            
            cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair=ADAUSD"
            cardanoresponse = urllib.request.urlopen(cardano_api_url)
            cardanodata = json.load(cardanoresponse)
            cardano_response = cardanodata['result']['ADAUSD']['c'][0]
            
            exchange=float(cardano_response)/float(response12)
            exchange = round(exchange, 4)
            return exchange*cardano_bitcoin_exchange
        elif exchange =="ETH":
            cardano_ethereum_exchange = int(input("How much Cardano(ADA) would you like to exchange in Ethereum(ETH)?"))
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
            
            cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair=ADAUSD"
            cardanoresponse = urllib.request.urlopen(cardano_api_url)
            cardanodata = json.load(cardanoresponse)
            cardano_response = cardanodata['result']['ADAUSD']['c'][0]
            
            exchange = float(cardano_response)/float(response123)
            exchange = round(exchange, 4)
            return exchange * cardano_ethereum_exchange
        elif exchange =="XRP":
            cardano_ripple_exchange =int(input("How much Cardano(ADA) would you like to exchange in Ripple(XRP)?"))
            
            ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
            xrpresponse = urllib.request.urlopen(ripple_api_url)
            xrpdata = json.load(xrpresponse)
            xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]
            
            cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair=ADAUSD"
            cardanoresponse = urllib.request.urlopen(cardano_api_url)
            cardanodata = json.load(cardanoresponse)
            cardano_response = cardanodata['result']['ADAUSD']['c'][0]
            
            exchange = float(cardano_response)/float(xrp_response)
            exchange = round(exchange, 4)
            return exchange*cardano_ripple_exchange
        elif exchange =="DOT":
            cardano_polkadot_exchange =int(input("How much Cardano(ADA) would you like to exchange in Polkadot(DOT)?"))
            
            polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair=DOTUSD"
            dotresponse = urllib.request.urlopen(polkadot_api_url)
            poldata = json.load(dotresponse)
            pol_response = poldata['result']['DOTUSD']['c'][0]
            
            cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair=ADAUSD"
            cardanoresponse = urllib.request.urlopen(cardano_api_url)
            cardanodata = json.load(cardanoresponse)
            cardano_response = cardanodata['result']['ADAUSD']['c'][0]
            
            exchange = float(cardano_response)/float(pol_response)
            exchange=round(exchange, 4)
            return exchange * cardano_polkadot_exchange
        elif exchange =="FIL":
            cardano_filecoin_exchange = int(input("How much Cardano(ADA) would you like to exchange in Filecoin(FIL)?"))
            
            filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=FILUSD"
            fileresponse = urllib.request.urlopen(filecoin_api_url)
            fildata = json.load(fileresponse)
            file_response = fildata['result']['FILUSD']['c'][0]
            
            cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair=ADAUSD"
            cardanoresponse = urllib.request.urlopen(cardano_api_url)
            cardanodata = json.load(cardanoresponse)
            cardano_response = cardanodata['result']['ADAUSD']['c'][0]
            
            exchange = float(cardano_response)/float(filecoin_response)
            exchange = round(exchange, 4)
            return exchange*cardano_filecoin_exchange
        elif exchange =="LINK":
            cardano_chainlink_exchange = int(input("How much Cardano(ADA) would you like to exchange in Chainlink(LINK)?"))
            
            chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair=LINKUSD"
            chainresponse = urllib.requestest.urlopen(chainlink_api_url)
            chaindata = json.load(chainresponse)
            chain_response = chaindata['result']['LINKUSD']['c'][0]
            
            cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair=ADAUSD"
            cardanoresponse = urllib.request.urlopen(cardano_api_url)
            cardanodata = json.load(cardanoresponse)
            cardano_response = cardanodata['result']['ADAUSD']['c'][0]
            
            exchange = float(cardano_response)/float(chain_response)
            exchange =round(exchange, 4)
            return exchange * cardano_chainlink_exchange
        elif exchange =="LTC":
            cardano_litecoin_exchange = int(input("How much Cardano(ADA) would you like to exchange in Litecoin(LTC)?"))
            
            litecoin_api_url ="https://api.kraken.com/0/public/Ticker?pair=LTCUSD"
            literesponse = urllib.request.urlopen(litecoin_api_url)
            litedata = json.load(literesponse)
            lite_response = litedata['result']['XLTCZUSD']['c'][0]
            
            cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair=ADAUSD"
            cardanoresponse = urllib.request.urlopen(cardano_api_url)
            cardanodata = json.load(cardanoresponse)
            cardano_response = cardanodata['result']['ADAUSD']['c'][0]
            
            exchange = float(cardano_response)/float(lite_response)
            exchange = round(exchange, 4)
            return exchange * cardano_litecoin_exchange
            
            
            
        else:
            print("Due to incorrect exchange order, we are unable to make an exchange currently!")

# %%
trading("ADA", "DOT")
# Out:
# Cardano(ADA). Which currency would you like to exchange it into? DOT
# How much Cardano(ADA) would you like ot exchange in Polkadot(DOT)? 5
# 0.17049999999999998

# %%
#currently I did exchange for XBT and ETH, XRP, DOT, FIl, LINK, I need to do the following: I am doing LTC
#LTC - Litecoin, #ADA - Cardano
# Out:
# The current price of Cardano(ADA) is: 1.417992

# %%
ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
xrpresponse = urllib.request.urlopen(ripple_api_url)
xrpdata = json.load(xrpresponse)
xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]

# %%
xrp_response
# Out:
# '1.92608000'

# %%
#trading("XBT", "ETH")

# %%
# Out:
# The current price of chainlink(LINK) is: 35.456670

# %%
# Out:
# the current price of Bitcoin(XBT) is: 63083.30000

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-151-ca20f3a9e1f0> in <module>
#       2 xbtresponse = urllib.request.urlopen(bitcoin_api_url)
#       3 xbtdata = json.load(xbtresponse)
# ----> 4 response12 = xbtdata['result']['XXBTZUSD']['c'][0]
#       5
#       6 api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair="+ticker+"USD"
#
# KeyError: 'XXBTZUSD'

# %%
def this_work_here(ticker, exchange):
    
    if ticker == "ETH":
        input(("Ethereum(ETH). Which currency would you like to exchange it into?"))
        if exchange == "ETH":
            print("Sorry, you cannot exchange Ethereum(ETH) for Ethereum(ETH). Would you like to make another exchange?")
        elif exchange == "XBT":
            
            ethereum_bitcoin_exchange = int(input("How much Ethereum(ETH) would you like to exchange in Bitcoin(XBT)?"))
            #ask how to do the mathematics in here
            bitcoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=XBTUSD"
            xbtresponse = urllib.request.urlopen(bitcoin_api_url)
            xbtdata = json.load(xbtresponse)
            response12 = xbtdata['result']['XXBTZUSD']['c'][0]
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
            
            exchange = float(response123) / float(response12)
            exchange = round(exchange, 4)
            return exchange * ethereum_bitcoin_exchange
        
        elif exchange == "XRP":
            
            ethereum_ripple_exchange = int(input("How much Ethereum(ETH) would you like to exchange in Ripple(XRP)?"))
            
                        
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
 
            
            ripple_api_url = "https://api.kraken.com/0/public/Ticker?pair=XRPUSD"
            xrpresponse = urllib.request.urlopen(ripple_api_url)
            xrpdata = json.load(xrpresponse)
            xrp_response = xrpdata['result']['XXRPZUSD']['c'][0]
            
            exchange = float(response123) / float(xrp_response)
            exchange = round(exchange, 4)
            return exchange * ethereum_ripple_exchange
        
        elif exchange == "DOT":
            
            ethereum_polkadot_exchange = int(input("How much Ethereum(ETH) would you like to exchange in Polkadot(DOT)"))
              
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
 
            
            polkadot_api_url = "https://api.kraken.com/0/public/Ticker?pair=DOTUSD"
            dotresponse = urllib.request.urlopen(polkadot_api_url)
            poldata = json.load(dotresponse)
            pol_response = poldata['result']['DOTUSD']['c'][0]
            
            exchange = float(response123) / float(pol_response)
            exchange = round(exchange, 4)
            return exchange * ethereum_polkadot_exchange
        
        elif exchange == "FIL":
            
            ethereum_filecoin_exchange = int(input("How much Ethereum(ETH) would you like to exchange in Filecoin(FIL)"))
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
 
            filecoin_api_url = "https://api.kraken.com/0/public/Ticker?pair=FILUSD"
            fileresponse = urllib.request.urlopen(filecoin_api_url)
            fildata = json.load(fileresponse)
            file_response = fildata['result']['FILUSD']['c'][0]
            
            exchange = float(response123) / float(file_response)
            exchange = round(exchange, 4)
            return exchange * ethereum_filecoin_exchange
        
        
        elif exchange == "LINK":
            
            ethereum_chainlink_exchange = int(input("How much Ethereum(ETH) would you like to exchange in Chainlink(LINK)?"))
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
 
            chainlink_api_url = "https://api.kraken.com/0/public/Ticker?pair=LINKUSD"
            chainresponse = urllib.request.urlopen(chainlink_api_url)
            chaindata = json.load(chainresponse)
            chain_response = chaindata['result']['LINKUSD']['c'][0]
            
            exchange = float(response123) / float(chain_response)
            exchange = round(exchange, 4)
            return exchange * ethereum_chainlink_exchange
            
            
        elif exchange =="LTC":
            
            ethereum_litecoin_exchange = int(input("How much Ethereum(ETH) would you like to exchange in Litecoin(LTC)?"))
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
 
            
            litecoin_api_url ="https://api.kraken.com/0/public/Ticker?pair=LTCUSD"
            literesponse = urllib.request.urlopen(litecoin_api_url)
            litedata = json.load(literesponse)
            lite_response = litedata['result']['XLTCZUSD']['c'][0]
            
            exchange = float(response123)/ float(lite_response)
            exchange = round(exchange, 4)
            return exchange * ethereum_litecoin_exchange
        
        elif exchange == "ADA":
            
            ethereum_cardano_exchange = int(input("How much Ethereum(ETH) would you like to exchange in Cardano(ADA)?"))
            
            api_conditions_url = "https://api.kraken.com/0/public/Ticker?pair=ETHUSD"
            ethresponse = urllib.request.urlopen(api_conditions_url)
            ethdata = json.load(ethresponse)
            response123 = ethdata['result']['XETHZUSD']['c'][0]
 
            cardano_api_url = "https://api.kraken.com/0/public/Ticker?pair=ADAUSD"
            cardanoresponse = urllib.request.urlopen(cardano_api_url)
            cardanodata = json.load(cardanoresponse)
            cardano_response = cardanodata['result']['ADAUSD']['c'][0]
            
            exchange = float(response123) / float(cardano_response)
            exchange = round(exchange, 4)
            return exchange * ethereum_cardano_exchange
        
        else:
            print("Due to incorrect exchange pick, we are unable to make an exchange currently!")

# %%
this_work_here("ETH", "LTC")
# Out:
# Ethereum(ETH). Which currency would you like to exchange it into? LTC
# How much Ethereum(ETH) would you like to exchange in Litecoin(LTC)? 2
# 16.8822
